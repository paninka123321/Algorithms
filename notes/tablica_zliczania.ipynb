# %%
lista1 = [4, 6, 9, 5, 2, 5, 3, 3, 3]
max(lista1)
# Out:
# 9

# %%
lista = [4, 6, 9, 5, 2, 5, 3, 3, 3]
maks = max(lista)
minimum = min(lista)
dlugosc = maks - minimum + 1
tab = [0] * dlugosc
for k in lista:
    for i in range(minimum, maks +1):
        if k == i:
            tab[i - minimum] +=1
            break

# %%
lista = [4, 6, 9, 5, 2, 5, 3, 3, 3]
maks = max(lista)
minimum = min(lista)
dlugosc = maks - minimum + 1
tab = [0] * dlugosc
for k in lista:
        tab[k - minimum] +=1

# %%
tab
# Out:
# [1, 3, 1, 2, 1, 0, 0, 1]

# %%
tab
# Out:
# [1, 3, 1, 2, 1, 0, 0, 1]

# %%
tablica=[3,4,9]
m=max(tablica) + 1
m
# Out:
# 10

# %%
tablica=[4, 6, 9, 5, 2, 5, 3, 3, 3]
m=max(tablica) + 1

tab = [0] * m
j = 0
for j in tablica:
    tab[j]=tab[j]+1

print(tab)
# Out:
# [0, 0, 1, 3, 1, 2, 1, 0, 0, 1]

# %%
lista2 = [2,5,4]
for j in lista2:
    print(j)
# Out:
# 2
# 5
# 4

# %%
tab = []

# %%
tab[0] = 1

# %%
tab
# Out:
# []

# %%
import numpy as np
np.append(tab,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/paulinakulczyk/Algorytmy/tablica_zliczania.ipynb Komórka 6 line 2
#       <a href='vscode-notebook-cell:/Users/paulinakulczyk/Algorytmy/tablica_zliczania.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> import numpy as np
# ----> <a href='vscode-notebook-cell:/Users/paulinakulczyk/Algorytmy/tablica_zliczania.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> tab.np.append(2)
#
# AttributeError: 'list' object has no attribute 'np'

# %% [markdown]
# ## Sorting + counting - sortowanie przez zliczanie

# %% [markdown]
# Basing on conting tab which starts from 0:

# %%
sorted_tab = []
j = 0
for i in tab:
    sorted_tab += i * [j]
    j += 1

# %%
sorted_tab
# Out:
# [2, 3, 3, 3, 4, 5, 5, 6, 9]

# %% [markdown]
# Basing on counting tab which starts from minimum value:

# %%
sorted_tab_adv = []
j = min(lista)
for i in tab:
    sorted_tab_adv += i * [j]
    j += 1

# %%
sorted_tab_adv
# Out:
# [2, 3, 3, 3, 4, 5, 5, 6, 9]

# %% [markdown]
# As we can see, we have tha same results. The second option is better, when it comes to storage staff
